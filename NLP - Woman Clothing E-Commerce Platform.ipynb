# %%
import pandas as pd
import numpy as np
import spacy

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the file
df = pd.read_excel(r"C:\Users\Pranav\Downloads\15. Capstone Case Study - NLP- Woman Clothing E-Commerce Platform\Womens Clothing Reviews Data.xlsx")

# %% [markdown]
# # Data Audit

# %%
df
# Out:
#        Product ID        Category Subcategory1 SubCategory2   Location  \
# 0             767       Initmates     Intimate    Intimates     Mumbai
# 1            1080         General      Dresses      Dresses  Bangalore
# 2            1077         General      Dresses      Dresses    Gurgaon
# 3            1049  General Petite      Bottoms        Pants    Chennai
# 4             847         General         Tops      Blouses  Bangalore
# ...           ...             ...          ...          ...        ...
# 23481        1104  General Petite      Dresses      Dresses    Gurgaon
# 23482         862  General Petite         Tops        Knits    Gurgaon
# 23483        1104  General Petite      Dresses      Dresses    Gurgaon
# 23484        1084         General      Dresses      Dresses    Gurgaon
# 23485        1104  General Petite      Dresses      Dresses    Chennai
#
#       Channel  Customer Age  \
# 0      Mobile            33
# 1      Mobile            34
# ...

# %%
#checking the percentage of null values
df.isna().mean()*100
# Out:
# Product ID         0.000000
# Category           0.059610
# Subcategory1       0.059610
# SubCategory2       0.059610
# Location           0.000000
# Channel            0.000000
# Customer Age       0.000000
# Review Title      16.222430
# Review Text        3.597888
# Rating             0.000000
# Recommend Flag     0.000000
# dtype: float64

# %%
#English language model with large vocabulary and pre-trained word vectors
nlp = spacy.load('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ')

# %%
#Creating a proper column name
df = df.rename(columns={'Product ID' : 'Product_ID','Customer Age' : 'Customer_Age', 'Review Text' : 'Review_Text', 'Recommend Flag': 'Recommend_Flag'})

# %%
df
# Out:
#        Product_ID        Category Subcategory1 SubCategory2   Location  \
# 0             767       Initmates     Intimate    Intimates     Mumbai
# 1            1080         General      Dresses      Dresses  Bangalore
# 2            1077         General      Dresses      Dresses    Gurgaon
# 3            1049  General Petite      Bottoms        Pants    Chennai
# 4             847         General         Tops      Blouses  Bangalore
# ...           ...             ...          ...          ...        ...
# 23481        1104  General Petite      Dresses      Dresses    Gurgaon
# 23482         862  General Petite         Tops        Knits    Gurgaon
# 23483        1104  General Petite      Dresses      Dresses    Gurgaon
# 23484        1084         General      Dresses      Dresses    Gurgaon
# 23485        1104  General Petite      Dresses      Dresses    Chennai
#
#       Channel  Customer_Age  \
# 0      Mobile            33
# 1      Mobile            34
# ...

# %%
#The Review_Title column has 16% missing values and is not relevant for model building.
df = df.drop('Review Title',axis=1)

# %%
#Dropping the missing values
df = df.dropna()

# %% [markdown]
# # Exploratory Analysis

# %%
#Bar chart for analysing the Category column
counts = df['Category'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
#Bar chart for analysing the Subcategory1 column
counts = df['Subcategory1'].value_counts()
counts.plot(kind='bar')
plt.xlabel('subcat1')
plt.ylabel('Count')
plt.show()

# %%
#Bar chart for analysing the SubCategory2 column
counts = df['SubCategory2'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Subcat2')
plt.ylabel('Count')
plt.show()

# %%
#Entire product data details 
grouped_data = df.groupby(['Category', 'Subcategory1','SubCategory2'])
category_subcategory_counts = grouped_data.size()
category_subcategory_counts
# Out:
# Category        Subcategory1  SubCategory2
# General         Bottoms       Casual bottoms       1
#                               Jeans              756
#                               Pants              811
#                               Shorts             304
#                               Skirts             575
#                 Dresses       Dresses           3619
#                 Jackets       Jackets            383
#                               Outerwear          241
#                 Tops          Blouses           1928
#                               Fine gauge         663
#                               Knits             3125
#                               Sweaters           864
#                 Trend         Trend               95
# General Petite  Bottoms       Jeans              348
#                               Pants              539
#                               Skirts             328
#                 Dresses       Dresses           2526
# ...

# %%
#The bar chart displays the count of customers from each location
counts = df['Location'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %%
#The pie chart illustrates the distribution of product purchases across different channels
counts = df['Channel'].value_counts()
plt.figure(figsize=(8, 8)) 
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1826d9dd520>,
# ...
#  [Text(-1.0667298429337773, -0.26849104676781904, 'Web'),
#   Text(1.0667298177958267, 0.2684911466422731, 'Mobile')],
#  [Text(-0.5818526416002421, -0.1464496618733558, '57.8%'),
#   Text(0.5818526278886327, 0.14644971635033074, '42.2%')])

# %%
#The bar chart displays the count of individuals who recommend and those who do not recommend the product
counts = df['Recommend_Flag'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Rec_flag')
plt.ylabel('Count')
plt.show()

# %%
#Creating a new column called 'Age_Category' to categorize the existing 'Age' column.
bins = [0, 25, 50, float('inf')]
labels = ['Below 25', '25-50', '50+']
df['Age_Category'] = pd.cut(df['Customer_Age'], bins=bins, labels=labels, right=False)

# %%
#A pie chart illustrating the age categories and their respective contributions to product purchases
counts = df['Age_Category'].value_counts()
plt.figure(figsize=(8, 8)) 
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1826d735be0>,
# ...
#  [Text(-0.9428875764157564, -0.5665359814176161, '25-50'),
#   Text(1.0040326965417579, 0.4493532511010534, '50+'),
#   Text(0.13193738319956724, 1.0920588477341553, 'Below 25')],
#  [Text(-0.5143023144085943, -0.30901962622779056, '67.2%'),
#   Text(0.5476541981136861, 0.24510177332784727, '29.0%'),
#   Text(0.07196584538158211, 0.5956684624004482, '3.8%')])

# %%
#Dividing the datas into train and test sets
train_set = df.sample(frac=0.8, random_state=42)
test_set = df.drop(train_set.index)

# %%
#Dropping null values from the train set
train_set.dropna(subset=['Review_Text'],axis=0,inplace=True)

# %%
train_set['Review_Text'].isna().sum()
# Out:
# 0

# %%
#This function is designed to preprocess text data by removing stopwords, punctuation, spaces, and digits, and then lemmatizing the remaining tokens to their base form
def clean_text(text):
    
    
    doc = nlp(text)
    clean_text =''
    for word in doc:
        if not word.is_stop and not word.is_punct and not word.is_space:
                clean_text = clean_text + str(word.lemma_) + ' '
    clean_text = clean_text.strip()
    return clean_text

# %%
#Applying the function for cleaning the Review_Text column in the training set
train_set['Review_Text'] = train_set['Review_Text'].apply(clean_text)

# %%
train_set['Review_Text'][2]
# Out:
# 'high hope dress want work initially order petite small usual size find outrageously small small fact zip reorder petite medium ok overall half comfortable fit nicely half tight layer somewhat cheap net layer imo major design flaw net layer sew directly zipper c'

# %%
import nltk

# %%
#The function is for understanding whether the sentiment is positive or negative
def sentiment_analysis(text):
    
    sid = SentimentIntensityAnalyzer()
    sentiment_score = sid.polarity_scores(text)
    
    if sentiment_score['compound'] >= 0.05:
        sentiment_label = 'positive'
    elif sentiment_score['compound'] <= -0.05:
        sentiment_label = 'negative'
    else:
        sentiment_label = 'neutral'
    
    return sentiment_label

# %%
#A new column 'sentiment' applying the above function to Review_Text for sentiment analysis
train_set['sentiment'] = train_set['Review_Text'].apply(sentiment_analysis)

# %%
train_set['Review_Text'][train_set['sentiment'] == 'negative']
# Out:
# 22803    work belt ivory color dark irl dingy light tan...
# 17739    hate send dress busty curvy figure look big ro...
# 3980     cute shoulder seam come halfway arm weird shap...
# 4453     literally unflattering thing try retailer slee...
# 10846    well regular boring cardigan go short sleeve d...
#                                ...
# 6097     fell love dress see online order right away sa...
# 1503     beautiful dress color pleat problem bust area ...
# 2123     tiny expert make busy bohemian shirtdress look...
# 11684    frustrated retailer top short lately 5'7 hit p...
# 9845     romper cute will deny rayon fabric feel like w...
# Name: Review_Text, Length: 492, dtype: object

# %%
review_index = 3502
specific_review = train_set.loc[review_index, 'Review_Text']
print(specific_review)
# Out:
# love buy color see complain mock neck collapse look messy unfortunately return sew understand happen

# %%
#Understanding what most frequent words are using for positive sentiment and negative sentiment
from collections import Counter

positive_reviews = train_set[train_set['sentiment'] == 'positive']
negative_reviews = train_set[train_set['sentiment'] == 'negative']


positive_tokens = positive_reviews['Review_Text'].str.split()
negative_tokens = negative_reviews['Review_Text'].str.split()


positive_word_freq = Counter(word for review in positive_tokens for word in review)
negative_word_freq = Counter(word for review in negative_tokens for word in review)


top_n = 10
top_positive_words = positive_word_freq.most_common(top_n)
top_negative_words = negative_word_freq.most_common(top_n)

# %%
top_positive_words
# Out:
# [('dress', 9345),
#  ('fit', 8744),
#  ('love', 8122),
#  ('size', 7913),
#  ('wear', 7869),
#  ('look', 7141),
#  ('like', 6048),
#  ('color', 5478),
#  ('great', 4879),
#  ('small', 4092)]

# %%
top_negative_words
# Out:
# [('look', 198),
#  ('dress', 190),
#  ('size', 168),
#  ('wear', 140),
#  ('fabric', 127),
#  ('order', 119),
#  ('cut', 106),
#  ('return', 105),
#  ('like', 102),
#  ('small', 101)]

# %%
#installing word cloud
pip install wordcloud
# Out:
# ...
#   Using cached wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Creating word clouds for the positive & negative reviews 
separately
from wordcloud import WordCloud

# %%
positive_text = ' '.join(positive_reviews['Review_Text'])
negative_text = ' '.join(negative_reviews['Review_Text'])

# %%
positive_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
negative_wordcloud = WordCloud(width=800, height=400, background_color='black').generate(negative_text)

#Ploting word clouds for positive and negative reviews
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(positive_wordcloud, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(negative_wordcloud, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')

plt.show()

# %%
positive_sentiments = positive_reviews['Review_Text']
negative_sentiments = negative_reviews['Review_Text']

# %%
#Understanding sentiment among the customers on the different categories by location
senti_cat_loc = train_set.groupby(['Location', 'Category', 'sentiment']).size().unstack(fill_value=0)

# %%
senti_cat_loc
# Out:
# sentiment                 negative  neutral  positive
# Location  Category
# Bangalore General               66       25      2282
#           General Petite        39       11      1351
#           Initmates              2        5       247
# Chennai   General               34        7      1006
#           General Petite        19        9       592
#           Initmates              4        3       100
# Gurgaon   General              126       48      3870
#           General Petite        52       28      2279
#           Initmates             10        4       400
# Mumbai    General               95       26      3100
#           General Petite        37       17      1832
#           Initmates              8        3       365

# %%
senti_cat_loc.plot(kind='bar',figsize=(15,10))
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %%
#Understanding sentiment among the customers on the  subcategory1 by location
senti_subcat_loc = train_set.groupby(['Location', 'Subcategory1', 'sentiment']).size().unstack(fill_value=0)

# %%
senti_subcat_loc
# Out:
# sentiment               negative  neutral  positive
# Location  Subcategory1
# Bangalore Bottoms             23        9       620
#           Dresses             25       11      1043
#           Intimate             3        5       279
#           Jackets              3        2       167
#           Tops                52       14      1744
#           Trend                1        0        27
# Chennai   Bottoms              8        2       288
#           Dresses             16        3       444
#           Intimate             5        5       120
#           Jackets              3        0        77
#           Tops                24        9       758
#           Trend                1        0        11
# Gurgaon   Bottoms             31       10      1021
#           Dresses             50       24      1828
#           Intimate            11        6       470
#           Jackets              9        3       305
#           Tops                84       36      2887
# ...

# %%
senti_subcat_loc.plot(kind='bar',figsize=(30,20))
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %%
#Understanding sentiment among the customers on the  subcategory2 by location
senti_subcat2_loc = train_set.groupby(['Location', 'SubCategory2', 'sentiment']).size().unstack(fill_value=0)
senti_subcat2_loc
# Out:
# sentiment               negative  neutral  positive
# Location  SubCategory2
# Bangalore Blouses             16        3       489
#           Dresses             25       11      1043
#           Fine gauge           5        3       197
#           Intimates            0        0        20
#           Jackets              2        1       112
# ...                          ...      ...       ...
# Mumbai    Skirts               1        1       235
#           Sleep                3        0        50
#           Sweaters            10        2       314
#           Swim                 1        0        88
#           Trend                1        0        17
#
# [73 rows x 3 columns]

# %%
senti_subcat2_loc.plot(kind='bar',figsize=(30,20))
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %%
#Understanding sentiment among the customers on the  category by age category
senti_cat_age = train_set.groupby(['Age_Category', 'Category', 'sentiment']).size().unstack(fill_value=0)
senti_cat_age
# Out:
# sentiment                    negative  neutral  positive
# Age_Category Category
# Below 25     General               12        3       373
#              General Petite         3        3       248
#              Initmates              0        1        51
# 25-50        General              219       67      6881
#              General Petite       106       42      4006
#              Initmates             19        6       806
# 50+          General               90       36      3004
#              General Petite        38       20      1800
#              Initmates              5        8       255

# %%
senti_cat_age.plot(kind='bar')
plt.xlabel('age')
plt.ylabel('Count')
plt.show()

# %%
#Understanding sentiment among the customers on the  subcategory1 by age category
senti_subcat_age = train_set.groupby(['Age_Category', 'Subcategory1', 'sentiment']).size().unstack(fill_value=0)
senti_subcat_age
senti_subcat_age.plot(kind='bar')
plt.xlabel('age')
plt.ylabel('Count')
plt.show()

# %%
#Understanding sentiment among the customers on the  subcategory2 by age category
senti_subcat2_age = train_set.groupby(['Age_Category', 'SubCategory2', 'sentiment']).size().unstack(fill_value=0)
senti_subcat2_age.plot(kind='bar',figsize=(30,10))
plt.xlabel('age')
plt.ylabel('Count')
plt.show()

# %%
#Understanding sentiment among the customers by channel
senti_channel = train_set.groupby(['Channel','sentiment']).size().unstack(fill_value=0)
senti_channel.plot(kind='bar',)
plt.xlabel('channel')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Predictive Analysis (Topic Mining)

# %%
#Using the subcategory2 column categories as labels for predicting the reviews is for identifying or classifying which products
labels = train_set['SubCategory2']

# %%
labels
# Out:
# 8329        Dresses
# 17943    Fine gauge
# 2157          Knits
# 11456          Swim
# 14386       Dresses
#             ...
# 319      Fine gauge
# 21838       Dresses
# 20038    Fine gauge
# 13051       Dresses
# 22210       Dresses
# Name: SubCategory2, Length: 18102, dtype: object

# %%
#Making the Feature column
x_train = train_set['Review_Text']

# %%
#Cleaning the data
x_train_w2v = []

docs = [nlp(x) for x in x_train]

# %%
for sent in docs:
    x_train_w2v.append(sent.vector)

# %%
x_train_w2v = np.array(x_train_w2v)

# %%
x_train_w2v.shape
# Out:
# (18102, 300)

# %%
x_features = pd.DataFrame(x_train_w2v)

# %%
#RandomForestClassifier for the predictions
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(x_features,labels)
# Out:
# RandomForestClassifier()

# %%
#Checking the precision score for the trained set
from sklearn.metrics import precision_score
y_train_pred = rf.predict(x_features)

# %%
precision = precision_score(labels, y_train_pred, average='weighted') * 100

# %%
precision
# Out:
# 99.9944768702115

# %% [markdown]
# It appears that the model is performing well in predicting outcomes on my test dataset

# %%
#Preparing the test_set
x_test = test_set['Review_Text']

# %%
test_docs = [nlp(x) for x in cleaned_x_test]

# %%
x_test_w2v = []
for sent in test_docs:
    x_test_w2v.append(sent.vector)

# %%
x_test_w2v = np.array(x_test_w2v)

# %%
x_test_w2v.shape
# Out:
# (4526, 300)

# %%
x_test_features = pd.DataFrame(x_test_w2v)

# %%
result = rf.predict(x_test_features)

# %%
test_data = pd.DataFrame({'Review_text' :x_test,'Predictions' : result})

# %%
#Final table of Review_text and Predictions
test_data
# Out:
#                                              Review_text Predictions
# 9      I'm 5"5' and 125 lbs. i ordered the s petite t...     Dresses
# 11     This dress is perfection! so pretty and flatte...     Dresses
# 13     Bought the black xs to go under the larkspur m...     Dresses
# 16     Material and color is nice.  the leg opening i...     Dresses
# 24     I love this shirt because when i first saw it,...     Dresses
# ...                                                  ...         ...
# 23466  This dress has a great design and fits very we...       Knits
# 23467  I worry when i have an elastic waist, or somet...     Dresses
# 23475  Cute dress but not for me.  the waist is too h...     Dresses
# 23483  This fit well, but the top was very see throug...       Knits
# 23485  This dress in a lovely platinum is feminine an...     Dresses
#
# [4526 rows x 2 columns]

# %%
#Analyzing the reviews for each product
test_data[test_data['Predictions']=='Sweaters']
# Out:
#                                              Review_text Predictions
# 964    I love this as a lounge-at-home top. the color...    Sweaters
# 977    This coat is a perfect fall to winter transiti...    Sweaters
# 2461   Love the unique look of this coat. living in t...    Sweaters
# 2870   The sweater is beautiful and lightweight. it i...    Sweaters
# 7236                                         Comfy cozy!    Sweaters
# 12525  This sweater is a great, oversized, warm, and ...    Sweaters
# 12882  Tried this on on a whim and so glad i did, it ...    Sweaters
# 16514  This is the kind of weather i want to wrap mys...    Sweaters
# 16647  This shirt is beautiful and well-made. the lac...    Sweaters
# 17027  I usually love a cowl neck sweater but not thi...    Sweaters
# 17912  Cozy and beautiful - everything dreamy sleep p...    Sweaters
# 18173  I am curvy and this top, while stylish and i l...    Sweaters
# 20672  This sweater has beautiful colors & cute fur c...    Sweaters
# ...

# %%
test_data[test_data['Predictions']=='Pants']
# Out:
#                                              Review_text Predictions
# 235    The blush stripes are subtle but they definite...       Pants
# 642    These are great pants. i love the fit and the ...       Pants
# 3451   I love these pants -- bought them in the musta...       Pants
# 7816   I love charlie pants. i've bought a few in the...       Pants
# 8279   I am 5'7, the length is perfect, i can wear it...       Pants
# 8499   I'm not petite, but i am short at 5'3 and whil...       Pants
# 11024  Waist is tight and thighs and legs are not. -n...       Pants
# 13521  This is beautiful fabric and a good fit, but i...       Pants
# 15963  I loved these pants. loved them so much that i...       Pants
# 16064  I wanted to love these pants since i hate supe...       Pants
# 18585  Ok, so this is true to size-- i recently had a...       Pants
# 18888  I agree with another reviewer who said to get ...       Pants
# 21523  I really, really wanted to love this jacket. u...       Pants
# ...

# %% [markdown]
# # Predictive Analysis (Classification)

# %%
#Target column
train_set['Recommend_Flag'].value_counts()
# Out:
# 1    14799
# 0     3303
# Name: Recommend_Flag, dtype: int64

# %%
#Analysing who all are recommending the products on the basis of sentiments
train_set.groupby(['Recommend_Flag','sentiment']).size().unstack(fill_value=0)
# Out:
# sentiment       negative  neutral  positive
# Recommend_Flag
# 0                    330       95      2878
# 1                    162       91     14546

# %%
##Analysing the Rating of products on the basis of sentiments
train_set.groupby(['Rating','sentiment']).size().unstack(fill_value=0)
# Out:
# sentiment  negative  neutral  positive
# Rating
# 1               125       22       506
# 2               126       39      1097
# 3               116       53      2100
# 4                59       36      3831
# 5                66       36      9890

# %%
#cleaning the text 
df['Review_Text'] = df['Review_Text'].apply(clean_text)
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_1556\146904970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review_Text'] = df['Review_Text'].apply(clean_text)

# %%
#Creating the feature and target columns
x = df['Review_Text']
y = df['Recommend_Flag']

# %%
x
# Out:
#        Product_ID        Category Subcategory1 SubCategory2   Location  \
# 0             767       Initmates     Intimate    Intimates     Mumbai
# 1            1080         General      Dresses      Dresses  Bangalore
# 2            1077         General      Dresses      Dresses    Gurgaon
# 3            1049  General Petite      Bottoms        Pants    Chennai
# 4             847         General         Tops      Blouses  Bangalore
# ...           ...             ...          ...          ...        ...
# 23481        1104  General Petite      Dresses      Dresses    Gurgaon
# 23482         862  General Petite         Tops        Knits    Gurgaon
# 23483        1104  General Petite      Dresses      Dresses    Gurgaon
# 23484        1084         General      Dresses      Dresses    Gurgaon
# 23485        1104  General Petite      Dresses      Dresses    Chennai
#
#       Channel  Customer_Age  \
# 0      Mobile            33
# 1      Mobile            34
# ...

# %%
#splitting the datas
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42,stratify=df['Recommend_Flag'])

# %%
#Importing the needed libraries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
#Converting the string datas into sparce object
vectorizer = CountVectorizer(ngram_range=(1,1))
train_vector = vectorizer.fit_transform(X_train)

# %%
train_vector.shape, y_train.shape
# Out:
# ((15839, 9692), (15839,))

# %%
#Smote for imbalanced target column
from imblearn.over_sampling import SMOTE

train_vector,y_train = os.fit_resample(train_vector,y_train)

# %%
y_train.value_counts()
# Out:
# 1    12968
# 0    12968
# Name: Recommend_Flag, dtype: int64

# %%
#Training and predictions
rf = RandomForestClassifier()
rf.fit(train_vector,y_train)
# Out:
# RandomForestClassifier()

# %%
#test_Data preparation
test_vector = vectorizer.transform(X_test)

# %%
test_vector,y_test = os.fit_resample(test_vector,y_test)

# %%
#Applying the predictions
y_train_pred = rf.predict(train_vector)

# %%
y_test_pred = rf.predict(test_vector)

# %%
#Checking the different prediction scores
from sklearn.metrics import accuracy_score,precision_score,recall_score

# %%
precision = precision_score(y_train, y_train_pred, average='weighted') * 100
accuracy = accuracy_score(y_train, y_train_pred)*100
recall = recall_score(y_train, y_train_pred, average='weighted')*100

print(f'Precision: {precision:}%')
print(f'Accuracy: {accuracy}%')
print(f'Recall: {recall}%')
# Out:
# Precision: 99.97302504816956%
# Accuracy: 99.97301048735349%
# Recall: 99.97301048735349%

# %%
precision = precision_score(y_test, y_test_pred, average='weighted') * 100
accuracy = accuracy_score(y_test, y_test_pred)*100
recall = recall_score(y_test, y_test_pred, average='weighted')*100

print(f'Precision: {precision:}%')
print(f'Accuracy: {accuracy}%')
print(f'Recall: {recall}%')
# Out:
# Precision: 89.16109493836758%
# Accuracy: 88.77495952509445%
# Recall: 88.77495952509445%

# %%
pd.crosstab(y_test_pred,y_test)
# Out:
# Recommend_Flag     0     1
# row_0
# 0               4659   348
# 1                900  5211

# %% [markdown]
# The prediction scores indicate that the model is performing well

# %% [markdown]
# # Predictive Analysis Based On Rating

# %%
#Creating the target column
y = df['Rating']

# %%
y.value_counts()
# Out:
# 5    12527
# 4     4908
# 3     2823
# 2     1549
# 1      821
# Name: Rating, dtype: int64

# %%
#Train test split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42,stratify=df['Rating'])

# %%
#data preprocessing
vectorizer = CountVectorizer(ngram_range=(1,1))

# %%
train_vector = vectorizer.fit_transform(X_train)
test_vector = vectorizer.transform(X_test)

# %%
#This library is using instead of PCA
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=50)

train_vector = svd.fit_transform(train_vector)
test_vector = svd.transform(test_vector)

# %%
#train_vector,y_train = os.fit_resample(train_vector,y_train)

# %%
y_train.value_counts()
# Out:
# 5    8769
# 4    3435
# 3    1976
# 2    1084
# 1     575
# Name: Rating, dtype: int64

# %%
#checking the svc model for predictions
svc = SVC()
svc.fit(train_vector,y_train)
# Out:
# SVC()

# %%
#test_vector,y_test = os.fit_resample(test_vector,y_test)

# %%
y_train_pred = svc.predict(train_vector)
y_test_pred = svc.predict(test_vector)

# %%
#These functions is for analysing the different prediction scores
def train_metrics(y_train,y_train_pred):
        precision = precision_score(y_train, y_train_pred, average='weighted') * 100
        accuracy = accuracy_score(y_train, y_train_pred)*100
        recall = recall_score(y_train, y_train_pred, average='weighted')*100

        print(f'Precision: {precision:}%')
        print(f'Accuracy: {accuracy}%')
        print(f'Recall: {recall}%')
        
        return train_metrics

# %%
def test_metrics(y_test,y_test_pred):
        precision = precision_score(y_test, y_test_pred, average='weighted') * 100
        accuracy = accuracy_score(y_test, y_test_pred)*100
        recall = recall_score(y_test, y_test_pred, average='weighted')*100

        print(f'Precision: {precision:}%')
        print(f'Accuracy: {accuracy}%')
        print(f'Recall: {recall}%')
        return train_metrics

# %%
train_matrics(y_train,y_train_pred)
# Out:
# Precision: 69.21611978595935%
# Accuracy: 66.86659511332786%
# Recall: 66.86659511332786%
# <function __main__.train_matrics(y_train, y_train_pred)>

# %%
test_metrics(y_test,y_test_pred)
# Out:
# Precision: 52.63371998003037%
# Accuracy: 58.06451612903226%
# Recall: 58.06451612903226%
# <function __main__.train_metrics(y_test, y_test_pred)>

# %%
#checking the RandomForestClassifier model for predictions
rf = RandomForestClassifier()
rf.fit(train_vector,y_train)
# Out:
# RandomForestClassifier()

# %%
y_train_pred = rf.predict(train_vector)
y_test_pred = rf.predict(test_vector)

# %%
train_matrics(y_train,y_train_pred)
# Out:
# Precision: 100.0%
# Accuracy: 100.0%
# Recall: 100.0%
# <function __main__.train_matrics(y_train, y_train_pred)>

# %%
test_metrics(y_test,y_test_pred)
# Out:
# Precision: 47.31094608799224%
# Accuracy: 56.60627485638533%
# Recall: 56.60627485638533%
# <function __main__.train_metrics(y_test, y_test_pred)>

# %%
#checking the KNeighborsClassifier model for predictions
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(train_vector,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_train_pred = knn.predict(train_vector)
y_test_pred = knn.predict(test_vector)
# Out:
# C:\Users\Pranav\Downloads\anacondas\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
train_matrics(y_train,y_train_pred)
# Out:
# Precision: 64.02166806638945%
# Accuracy: 65.52812677568028%
# Recall: 65.52812677568028%
# <function __main__.train_matrics(y_train, y_train_pred)>

# %%
test_metrics(y_test,y_test_pred)
# Out:
# Precision: 46.2243920665931%
# Accuracy: 49.2414199440271%
# Recall: 49.2414199440271%
# <function __main__.train_metrics(y_test, y_test_pred)>

# %%
#checking the DecisionTreeClassifier model for predictions
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(train_vector,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred = dt.predict(train_vector)
y_test_pred = dt.predict(test_vector)

# %%
train_matrics(y_train,y_train_pred)
# Out:
# Precision: 100.0%
# Accuracy: 100.0%
# Recall: 100.0%
# <function __main__.train_matrics(y_train, y_train_pred)>

# %%
test_metrics(y_test,y_test_pred)
# Out:
# Precision: 44.03163193244752%
# Accuracy: 42.96656355869789%
# Recall: 42.96656355869789%
# <function __main__.train_metrics(y_test, y_test_pred)>

# %% [markdown]
# It seems like the SVC model performs better compared to others, suggesting that none of the models used provide satisfactory predictions. If necessary, we can proceed with the SVC model
